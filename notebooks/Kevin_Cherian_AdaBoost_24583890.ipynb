# %%
import pandas as pd
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/df_cleaned_num.csv')
# df = pd.read_csv('C:/Users/kevin/Downloads/UTS/Sem 5/36120 Advanced Machine Learning Application/AT3/Data/df_cleaned_num.csv')

# %%
df
# Out:
#        totalTravelDistance  totalFare  travelDurationHours  numSegments  \
# 0                   3310.0     620.10            11.566667            3
# 1                   3438.0    1301.10            16.083333            3
# 2                   2335.0     537.20            13.933333            2
# 3                   1689.0     567.00             8.433333            2
# 4                   2556.0     866.71            14.550000            3
# ...                    ...        ...                  ...          ...
# 22281               1580.0     192.60             6.266667            2
# 22282               1601.0     232.20            10.833333            2
# 22283               2314.0     268.60             7.016667            2
# 22284               1321.0     493.60             7.366667            2
# 22285               1191.0     239.60             6.183333            2
#
#        daysUntilDeparture  startingAirport_encoded  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22286 entries, 0 to 22285
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   totalTravelDistance         22286 non-null  float64
#  1   totalFare                   22286 non-null  float64
#  2   travelDurationHours         22286 non-null  float64
#  3   numSegments                 22286 non-null  int64
#  4   daysUntilDeparture          22286 non-null  int64
#  5   startingAirport_encoded     22286 non-null  int64
#  6   destinationAirport_encoded  22286 non-null  int64
#  7   isNonStop_encoded           22286 non-null  int64
#  8   isBasicEconomy_encoded      22286 non-null  int64
#  9   isRefundable_encoded        22286 non-null  int64
#  10  cabinType_encoded           22286 non-null  int64
#  11  timeBlock_encoded           22286 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 2.0 MB

# %%
df.describe()
# Out:
#        totalTravelDistance     totalFare  travelDurationHours   numSegments  \
# count         22286.000000  22286.000000         22286.000000  22286.000000
# mean           1559.662927    385.641638             6.901093      1.801086
# std             838.624371    214.520576             3.697141      0.592724
# min              97.000000     23.970000             0.800000      1.000000
# 25%             862.000000    231.700000             4.050000      1.000000
# 50%            1392.000000    354.200000             6.483333      2.000000
# 75%            2337.000000    501.600000             9.266667      2.000000
# max            3958.000000   3304.610000            23.150000      4.000000
#
#        daysUntilDeparture  startingAirport_encoded  \
# count        22286.000000             22286.000000
# mean            27.011397                 7.543346
# std             17.109154                 4.608679
# min              1.000000                 0.000000
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from numpy import mean
from numpy import std

# %%
X = df.drop(['totalFare'], axis=1)
y = df[['totalFare']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
classifier = AdaBoostRegressor()

# %%
classifier.fit(X_train, y_train)
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostRegressor()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score

# %%
cv = RepeatedKFold(n_splits = 10, n_repeats = 3, random_state = 1)
n_scores = cross_val_score(classifier, X, y, scoring =
    'neg_mean_absolute_error', cv = cv, n_jobs = -1, error_score =
    'raise')
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ...

# %%
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MAE: -210.845 (36.725)

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 57552.01582502506
# Mean Absolute Error: 185.19988524658166
# R^2 Score: -0.11614887283019315

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#param_grid = {
#    'n_estimators': [100, 300, 500],                
#    'learning_rate': [0.01, 0.05, 0.1]}
param_grid = {
    'n_estimators': [5, 10, 25, 50, 100, 300, 500],                
    'learning_rate': [0.001, 0.0025, 0.005, 0.01, 0.025, 0.05, 0.1]}

# %%
random_search = RandomizedSearchCV(
    estimator=classifier,
    param_distributions=param_grid,
    n_iter=100,  # Number of parameter settings sampled
    scoring='neg_mean_squared_error',  # Optimization metric
    cv=5,  # 5-fold cross-validation
    verbose=1,
    n_jobs=-1,  # Use all available cores
    random_state=42
)

# %%
random_search.fit(X_train, y_train)
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 49 is smaller than n_iter=100. Running 49 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
best_adab = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'n_estimators': 50, 'learning_rate': 0.05}

# %%
# Make predictions on the test set using the best model
y_pred = best_adab.predict(X_test)

# %%
# Evaluate the tuned model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 29579.3162126799
# Mean Absolute Error: 121.56859757917874
# R^2 Score: 0.4263464106931453

# %%
import joblib

joblib.dump(best_adab, '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/models/kevin_adaboost.pkl')
print("Model saved as 'kevin_adaboost.pkl'")
# Out:
# Model saved as 'kevin_adaboost.pkl'
