# %%
import pandas as pd
import numpy
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pip install -i https://test.pypi.org/simple/ my_krml_25076922==2024.0.3.4
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/df_cleaned_num.csv')

# %%
from my_krml_25076922.data.sets import load_sets

X_train, y_train, X_val, y_val, X_test, y_test = load_sets(path='/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/')

# %%
from sklearn.ensemble import AdaBoostRegressor

adaboost = AdaBoostRegressor(random_state=0, n_estimators=100)

# %%
adaboost.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
from joblib import dump

dump(adaboost,  '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/models/adaboost_default.joblib')
# Out:
# ['/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/models/adaboost_default.joblib']

# %%
y_train_preds = adaboost.predict(X_train)
y_val_preds = adaboost.predict(X_val)

# %%
from my_krml_25076922.models.performance import print_regressor_scores

print_regressor_scores(y_preds=y_train_preds, y_actuals=y_train, set_name='Training')
print_regressor_scores(y_preds=y_val_preds, y_actuals=y_val, set_name='Validation')
# Out:
# RMSE Training: 213.16962378097165
# MAE Training: 166.92519906757488
# RMSE Validation: 222.68316099734514
# MAE Validation: 168.21664109921676

# %%
from my_krml_25076922.models.performance import fit_assess_regressor

# %%
model1 = fit_assess_regressor(AdaBoostRegressor(random_state=0, n_estimators=100, learning_rate=0.05), X_train, y_train, X_val, y_val)
# Out:
# RMSE Training: 172.18930838594238
# MAE Training: 133.64518365287472
# RMSE Validation: 182.80870795547762
# MAE Validation: 135.5758104899634

# %%
# Solution:
model2 = fit_assess_regressor(AdaBoostRegressor(random_state=0, n_estimators=100, learning_rate=0.05, loss='square'), X_train, y_train, X_val, y_val)
# Out:
# RMSE Training: 186.0310045767471
# MAE Training: 143.23710653492253
# RMSE Validation: 196.16682061580934
# MAE Validation: 144.77492900562825
