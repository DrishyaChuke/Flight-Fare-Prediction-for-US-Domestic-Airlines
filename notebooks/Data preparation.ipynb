# %%
import zipfile
import os
import pandas as pd
import numpy
# Out:
# /Users/vega7unk/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
zip_dir = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/ATL'

# Directory to extract CSV files
extract_dir = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/ATL'

# The output CSV file where all data will be merged
output_csv = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ATL_merged.csv'

os.makedirs(extract_dir, exist_ok=True)

# %%
# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ATL_merged.csv.

# %%
df = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ATL_merged.csv')

# %%
df.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  ee4aaff43c557e1704ebf52b8abf25ad  2022-05-13  2022-06-15             ATL
# 1  284bffb121ffdafba55f69d6d89a4b7d  2022-05-13  2022-06-15             ATL
# 2  8efdd07b82644146d45978f61d081f3b  2022-05-13  2022-06-15             ATL
# 3  e03c8964b4feb4e206636a9c5c0015b2  2022-05-13  2022-06-15             ATL
# 4  f44658d6761962cecc3eabc0a29d6ef9  2022-05-13  2022-06-15             ATL
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                BOS        PT8H51M           False         False      False
# 1                BOS       PT12H31M           False         False      False
# 2                BOS        PT4H35M           False         False      False
# 3                BOS        PT4H38M           False         False      False
# 4                BOS        PT6H43M           False         False      False
#
# ...

# %%
df.shape
# Out:
# (874069, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874069 entries, 0 to 874068
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              874069 non-null  object
#  1   searchDate                         874069 non-null  object
#  2   flightDate                         874069 non-null  object
#  3   startingAirport                    874069 non-null  object
#  4   destinationAirport                 874069 non-null  object
#  5   travelDuration                     874069 non-null  object
#  6   isBasicEconomy                     874069 non-null  bool
#  7   isRefundable                       874069 non-null  bool
#  8   isNonStop                          874069 non-null  bool
#  9   totalFare                          874069 non-null  float64
#  10  totalTravelDistance                769021 non-null  float64
# ...

# %%
zip_dir_bos = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/BOS'

# Directory to extract CSV files
extract_dir_bos = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/BOS'

# The output CSV file where all data will be merged
output_csv_bos = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/BOS_merged.csv'

os.makedirs(extract_dir_bos, exist_ok=True)

# %%
# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_bos):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_bos, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_bos)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_bos, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_bos, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_bos}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/BOS_merged.csv.

# %%
df_BOS = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/BOS_merged.csv')

# %%
df_BOS.shape
# Out:
# (989175, 23)

# %%
df_BOS.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  9a5a4eb6d6c5c96d69ff46ad3c12d309  2022-04-18  2022-05-22             BOS
# 1  0873a112be6674c43a495117de163a03  2022-04-18  2022-05-22             BOS
# 2  5a79fde77bc19dac99075d497a52fbd5  2022-04-18  2022-05-22             BOS
# 3  39c570dfaef5ba1e7185517ff0c24aea  2022-04-18  2022-05-22             BOS
# 4  5816d779a59982c599dfe5635e73a6e6  2022-04-18  2022-05-22             BOS
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL       PT11H15M           False         False      False
# 1                ATL        PT2H59M           False         False       True
# 2                ATL        PT9H29M           False         False      False
# 3                ATL        PT2H59M           False         False       True
# 4                ATL           PT3H           False         False       True
#
# ...

# %%
df_BOS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989175 entries, 0 to 989174
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              989175 non-null  object
#  1   searchDate                         989175 non-null  object
#  2   flightDate                         989175 non-null  object
#  3   startingAirport                    989175 non-null  object
#  4   destinationAirport                 989175 non-null  object
#  5   travelDuration                     989175 non-null  object
#  6   isBasicEconomy                     989175 non-null  bool
#  7   isRefundable                       989175 non-null  bool
#  8   isNonStop                          989175 non-null  bool
#  9   totalFare                          989175 non-null  float64
#  10  totalTravelDistance                938789 non-null  float64
# ...

# %%
zip_dir_clt = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/CLT'

# Directory to extract CSV files
extract_dir_clt = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/CLT'

# The output CSV file where all data will be merged
output_csv_clt = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/CLT_merged.csv'

os.makedirs(extract_dir_clt, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_clt):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_clt, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_clt)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_clt, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_clt, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_clt}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/CLT_merged.csv.

# %%
df_CLT = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/CLT_merged.csv')

# %%
df_CLT.shape
# Out:
# (854536, 23)

# %%
df_CLT.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  30e9e8f5d925591585451d8f2f1a74ae  2022-05-19  2022-05-31             CLT
# 1  3172f0b8d27f9be423cda9f20cac2685  2022-05-19  2022-05-31             CLT
# 2  b6536e49b0d96e45256e6fe0259f1111  2022-05-19  2022-05-31             CLT
# 3  d21174436660b40efb10b58bbff79a52  2022-05-19  2022-05-31             CLT
# 4  fcf0c6ee9bdd6d436a409e2b43834d4f  2022-05-19  2022-05-31             CLT
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL       PT11H33M            True         False      False
# 1                ATL        PT8H17M           False         False      False
# 2                ATL       PT11H10M           False         False      False
# 3                ATL       PT12H24M           False         False      False
# 4                ATL         PT6H1M           False         False      False
#
# ...

# %%
df_CLT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854536 entries, 0 to 854535
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              854536 non-null  object
#  1   searchDate                         854536 non-null  object
#  2   flightDate                         854536 non-null  object
#  3   startingAirport                    854536 non-null  object
#  4   destinationAirport                 854536 non-null  object
#  5   travelDuration                     854536 non-null  object
#  6   isBasicEconomy                     854536 non-null  bool
#  7   isRefundable                       854536 non-null  bool
#  8   isNonStop                          854536 non-null  bool
#  9   totalFare                          854536 non-null  float64
#  10  totalTravelDistance                818065 non-null  float64
# ...

# %%
zip_dir_den = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/DEN'

# Directory to extract CSV files
extract_dir_den = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/DEN'

# The output CSV file where all data will be merged
output_csv_den = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DEN_merged.csv'

os.makedirs(extract_dir_den, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_den):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_den, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_den)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_den, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_den, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_den}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DEN_merged.csv.

# %%
df_DEN = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DEN_merged.csv')

# %%
df_DEN.shape
# Out:
# (770429, 23)

# %%
df_DEN.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  c4c15e7477db14816d98a386e73565f3  2022-05-18  2022-06-06             DEN
# 1  70ab7b83ef88886725bbe8e303178a3b  2022-05-18  2022-06-06             DEN
# 2  f97c09a0c43c5cd3614d3dade8a18e8b  2022-05-18  2022-06-06             DEN
# 3  330f7175c4ed2c518e46fca1155af3f7  2022-05-18  2022-06-06             DEN
# 4  b92770186538da8daaf0e3fae6471ecf  2022-05-18  2022-06-06             DEN
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                DTW        PT5H54M           False         False      False
# 1                DTW        PT6H24M           False         False      False
# 2                DTW        PT4H42M           False         False      False
# 3                EWR        PT3H41M           False         False       True
# 4                EWR        PT6H51M           False         False      False
#
# ...

# %%
df_DEN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770429 entries, 0 to 770428
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              770429 non-null  object
#  1   searchDate                         770429 non-null  object
#  2   flightDate                         770429 non-null  object
#  3   startingAirport                    770429 non-null  object
#  4   destinationAirport                 770429 non-null  object
#  5   travelDuration                     770429 non-null  object
#  6   isBasicEconomy                     770429 non-null  bool
#  7   isRefundable                       770429 non-null  bool
#  8   isNonStop                          770429 non-null  bool
#  9   totalFare                          770429 non-null  float64
#  10  totalTravelDistance                735319 non-null  float64
# ...

# %%
zip_dir_dfw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/DFW'

# Directory to extract CSV files
extract_dir_dfw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/DFW'

# The output CSV file where all data will be merged
output_csv_dfw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DFW_merged.csv'

os.makedirs(extract_dir_dfw, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_dfw):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_dfw, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_dfw)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_dfw, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_dfw, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_dfw}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DFW_merged.csv.

# %%
df_DFW = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DFW_merged.csv')

# %%
df_DFW.shape
# Out:
# (896596, 23)

# %%
df_DFW.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  5db2f9ca9401fcafd601c699eec6c9dc  2022-04-19  2022-05-21             DFW
# 1  1d1d1df31936643921f62bb7e17c41b5  2022-04-19  2022-05-21             DFW
# 2  2a44a4b90de67adeeb9d5f2d2169a3ef  2022-04-19  2022-05-21             DFW
# 3  8357772132251b9c07bc5a1bc76b52ce  2022-04-19  2022-05-21             DFW
# 4  e300325495de1f8202dc5dff3b20d012  2022-04-19  2022-05-21             DFW
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL         PT2H8M           False         False       True
# 1                ATL        PT2H15M           False         False       True
# 2                ATL         PT2H4M            True         False       True
# 3                ATL         PT2H5M            True         False       True
# 4                ATL         PT2H5M            True         False       True
#
# ...

# %%
df_DFW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896596 entries, 0 to 896595
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              896596 non-null  object
#  1   searchDate                         896596 non-null  object
#  2   flightDate                         896596 non-null  object
#  3   startingAirport                    896596 non-null  object
#  4   destinationAirport                 896596 non-null  object
#  5   travelDuration                     896596 non-null  object
#  6   isBasicEconomy                     896596 non-null  bool
#  7   isRefundable                       896596 non-null  bool
#  8   isNonStop                          896596 non-null  bool
#  9   totalFare                          896596 non-null  float64
#  10  totalTravelDistance                791866 non-null  float64
# ...

# %%
zip_dir_dtw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/DTW'

# Directory to extract CSV files
extract_dir_dtw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/DTW'

# The output CSV file where all data will be merged
output_csv_dtw = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DTW_merged.csv'

os.makedirs(extract_dir_dtw, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_dtw):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_dtw, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_dtw)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_dtw, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_dtw, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_dtw}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DTW_merged.csv.

# %%
df_DTW = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/DTW_merged.csv')

# %%
df_DTW.shape
# Out:
# (747751, 23)

# %%
df_DTW.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  ffe5536aaa49525a5140ef19343a301d  2022-05-01  2022-05-19             DTW
# 1  6ea22400a4518557ec207fc47b933d7e  2022-05-01  2022-05-19             DTW
# 2  ff2dffc6f115ac5ef4901a5a69f1ef44  2022-05-01  2022-05-19             DTW
# 3  3395b38e1cf1ad4fcd935f752b705f10  2022-05-01  2022-05-19             DTW
# 4  62960ee1bcb5b69f34688168f0b68d9e  2022-05-01  2022-05-19             DTW
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL         PT2H6M           False         False       True
# 1                ATL        PT1H58M           False         False       True
# 2                ATL        PT6H44M           False         False      False
# 3                ATL        PT5H29M           False         False      False
# 4                ATL        PT7H26M           False         False      False
#
# ...

# %%
df_DTW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747751 entries, 0 to 747750
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              747751 non-null  object
#  1   searchDate                         747751 non-null  object
#  2   flightDate                         747751 non-null  object
#  3   startingAirport                    747751 non-null  object
#  4   destinationAirport                 747751 non-null  object
#  5   travelDuration                     747751 non-null  object
#  6   isBasicEconomy                     747751 non-null  bool
#  7   isRefundable                       747751 non-null  bool
#  8   isNonStop                          747751 non-null  bool
#  9   totalFare                          747751 non-null  float64
#  10  totalTravelDistance                659173 non-null  float64
# ...

# %%
zip_dir_ewr = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/EWR'

# Directory to extract CSV files
extract_dir_ewr = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/EWR'

# The output CSV file where all data will be merged
output_csv_ewr = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/EWR_merged.csv'

os.makedirs(extract_dir_dtw, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_ewr):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_ewr, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_ewr)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_ewr, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_ewr, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_ewr}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/EWR_merged.csv.

# %%
df_EWR = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/EWR_merged.csv')

# %%
df_EWR.shape
# Out:
# (699628, 23)

# %%
df_EWR.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  fbf52ce4fe8aa3b178d2b922e1f290f9  2022-04-19  2022-05-23             EWR
# 1  6ecf39ef67f0197e7d9e0ec88bffb1ee  2022-04-19  2022-05-23             EWR
# 2  32703eee6b414c8189f23fa3c50cbe92  2022-04-19  2022-05-23             EWR
# 3  58a627cd72a301da26d66e8374b777c0  2022-04-19  2022-05-23             EWR
# 4  b38cfe2b5616cb5d41a33f0567bd39ed  2022-04-19  2022-05-23             EWR
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT6H39M           False         False      False
# 1                ATL        PT9H43M           False         False      False
# 2                ATL       PT12H32M           False         False      False
# 3                ATL        PT3H44M            True         False      False
# 4                ATL        PT3H54M            True         False      False
#
# ...

# %%
df_EWR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699628 entries, 0 to 699627
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              699628 non-null  object
#  1   searchDate                         699628 non-null  object
#  2   flightDate                         699628 non-null  object
#  3   startingAirport                    699628 non-null  object
#  4   destinationAirport                 699628 non-null  object
#  5   travelDuration                     699628 non-null  object
#  6   isBasicEconomy                     699628 non-null  bool
#  7   isRefundable                       699628 non-null  bool
#  8   isNonStop                          699628 non-null  bool
#  9   totalFare                          699628 non-null  float64
#  10  totalTravelDistance                618446 non-null  float64
# ...

# %%
zip_dir_iad = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/IAD'

# Directory to extract CSV files
extract_dir_iad = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/IAD'

# The output CSV file where all data will be merged
output_csv_iad = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/IAD_merged.csv'

os.makedirs(extract_dir_iad, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_iad):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_iad, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_iad)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_iad, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_iad, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_iad}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/IAD_merged.csv.

# %%
df_IAD = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/IAD_merged.csv')

# %%
df_IAD.shape
# Out:
# (594215, 23)

# %%
df_IAD.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  c259426b5ea906ad01d009f562505a05  2022-05-11  2022-05-15             IAD
# 1  50a1bd60d11d2553fdfc5acaf6e52c81  2022-05-11  2022-05-15             IAD
# 2  4480044d752e3442a98de0a01f68d4e4  2022-05-11  2022-05-15             IAD
# 3  e2bcfc746c7174b1b04d7431c6e51a04  2022-05-11  2022-05-15             IAD
# 4  132fb5f3b9f011a021525322236ad15b  2022-05-11  2022-05-15             IAD
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT1H43M           False         False       True
# 1                ATL        PT1H44M           False         False       True
# 2                ATL         PT2H1M           False         False       True
# 3                ATL        PT3H57M           False         False      False
# 4                ATL        PT1H46M           False         False       True
#
# ...

# %%
df_IAD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594215 entries, 0 to 594214
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              594215 non-null  object
#  1   searchDate                         594215 non-null  object
#  2   flightDate                         594215 non-null  object
#  3   startingAirport                    594215 non-null  object
#  4   destinationAirport                 594215 non-null  object
#  5   travelDuration                     594215 non-null  object
#  6   isBasicEconomy                     594215 non-null  bool
#  7   isRefundable                       594215 non-null  bool
#  8   isNonStop                          594215 non-null  bool
#  9   totalFare                          594215 non-null  float64
#  10  totalTravelDistance                590280 non-null  float64
# ...

# %%
zip_dir_jfk = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/JFK'

# Directory to extract CSV files
extract_dir_jfk = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/JFK'

# The output CSV file where all data will be merged
output_csv_jfk = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/JFK_merged.csv'

os.makedirs(extract_dir_jfk, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_jfk):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_jfk, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_jfk)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_jfk, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_jfk, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_jfk}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/JFK_merged.csv.

# %%
df_JFk = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/JFK_merged.csv')

# %%
df_JFk.shape
# Out:
# (688263, 23)

# %%
df_JFk.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  57ceb3c7b1a9fa75c4c0c75758369a66  2022-04-18  2022-06-07             JFK
# 1  9e2680991774b3c309d32626f144316c  2022-04-18  2022-06-07             JFK
# 2  3e6bb30fe20e5092962e737728a4b342  2022-04-18  2022-06-07             JFK
# 3  ce43836e813466045801d44c421fb18a  2022-04-18  2022-06-07             JFK
# 4  e38193690139b4b8ce6628cf352b317c  2022-04-18  2022-06-07             JFK
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT2H20M            True         False       True
# 1                ATL        PT2H26M           False         False       True
# 2                ATL        PT2H29M           False         False       True
# 3                ATL        PT2H30M           False         False       True
# 4                ATL        PT2H43M            True         False       True
#
# ...

# %%
df_LAX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688263 entries, 0 to 688262
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              688263 non-null  object
#  1   searchDate                         688263 non-null  object
#  2   flightDate                         688263 non-null  object
#  3   startingAirport                    688263 non-null  object
#  4   destinationAirport                 688263 non-null  object
#  5   travelDuration                     688263 non-null  object
#  6   isBasicEconomy                     688263 non-null  bool
#  7   isRefundable                       688263 non-null  bool
#  8   isNonStop                          688263 non-null  bool
#  9   totalFare                          688263 non-null  float64
#  10  totalTravelDistance                684750 non-null  float64
# ...

# %%
zip_dir_lax = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/LAX'

# Directory to extract CSV files
extract_dir_lax = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/LAX'

# The output CSV file where all data will be merged
output_csv_lax = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LAX_merged.csv'

os.makedirs(extract_dir_lax, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_lax):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_lax, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_lax)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_lax, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_lax, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_lax}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LAX_merged.csv.

# %%
df_LAX = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LAX_merged.csv')

# %%
df_LAX.shape
# Out:
# (1352275, 23)

# %%
df_LAX.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  3aec6033b2424dada16a9382127f50de  2022-05-06  2022-05-14             LAX
# 1  55afa61db5c00de7b3e1dcac4974844a  2022-05-06  2022-05-14             LAX
# 2  f133c251d7d0a341c0efa12b5883694c  2022-05-06  2022-05-14             LAX
# 3  71f47fdbe07b0dfbeffd0d879d4bcc81  2022-05-06  2022-05-14             LAX
# 4  e3802867917e138890f55f4ab47e7998  2022-05-06  2022-05-14             LAX
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                DTW        PT8H26M           False         False      False
# 1                DTW       PT10H37M           False         False      False
# 2                DTW       PT13H26M           False         False      False
# 3                DTW        PT6H35M           False         False      False
# 4                DTW        PT6H43M           False         False      False
#
# ...

# %%
df_LAX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1352275 entries, 0 to 1352274
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   legId                              1352275 non-null  object
#  1   searchDate                         1352275 non-null  object
#  2   flightDate                         1352275 non-null  object
#  3   startingAirport                    1352275 non-null  object
#  4   destinationAirport                 1352275 non-null  object
#  5   travelDuration                     1352275 non-null  object
#  6   isBasicEconomy                     1352275 non-null  bool
#  7   isRefundable                       1352275 non-null  bool
#  8   isNonStop                          1352275 non-null  bool
#  9   totalFare                          1352275 non-null  float64
#  10  totalTravelDistance                1230243 non-null  float64
# ...

# %%
zip_dir_lga = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/LGA'

# Directory to extract CSV files
extract_dir_lga = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/LGA'

# The output CSV file where all data will be merged
output_csv_lga = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LGA_merged.csv'

os.makedirs(extract_dir_lga, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_lga):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_lga, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_lga)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_lga, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_lga, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_lga}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LGA_merged.csv.

# %%
df_LGA = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/LGA_merged.csv')

# %%
df_LGA.shape
# Out:
# (1021938, 23)

# %%
df_LGA.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  4b2bfd6a588f5eb96996da7b59e99105  2022-05-05  2022-06-17             LGA
# 1  37029bf671cd38c89292ad4cddc42116  2022-05-05  2022-06-17             LGA
# 2  7fafa91a111bc87925faf4c8a77d2873  2022-05-05  2022-06-17             LGA
# 3  5dc7616b73b0c137a6cf2cbc88037d9b  2022-05-05  2022-06-17             LGA
# 4  03e9b9dd1e89b9e7f702484b79554501  2022-05-05  2022-06-17             LGA
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT2H29M           False         False       True
# 1                ATL        PT2H32M           False         False       True
# 2                ATL        PT5H50M           False         False      False
# 3                ATL        PT7H58M           False         False      False
# 4                ATL       PT11H11M           False         False      False
#
# ...

# %%
df_LGA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1021938 entries, 0 to 1021937
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   legId                              1021938 non-null  object
#  1   searchDate                         1021938 non-null  object
#  2   flightDate                         1021938 non-null  object
#  3   startingAirport                    1021938 non-null  object
#  4   destinationAirport                 1021938 non-null  object
#  5   travelDuration                     1021938 non-null  object
#  6   isBasicEconomy                     1021938 non-null  bool
#  7   isRefundable                       1021938 non-null  bool
#  8   isNonStop                          1021938 non-null  bool
#  9   totalFare                          1021938 non-null  float64
#  10  totalTravelDistance                978386 non-null   float64
# ...

# %%
zip_dir_mia = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/MIA'

# Directory to extract CSV files
extract_dir_mia = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/MIA'

# The output CSV file where all data will be merged
output_csv_mia = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/MIA_merged.csv'

os.makedirs(extract_dir_mia, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_mia):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_mia, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_mia)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_mia, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_mia, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_mia}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/MIA_merged.csv.

# %%
df_MIA = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/MIA_merged.csv')

# %%
df_MIA.shape
# Out:
# (875288, 23)

# %%
df_MIA.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  d12d139c76a395b01a119ae6bb633130  2022-04-23  2022-05-05             MIA
# 1  d589fb649619f63feab8b8d9d9f5f4de  2022-04-23  2022-05-05             MIA
# 2  2e9d28ce20e10a1e2f4b85911e8f47b8  2022-04-23  2022-05-05             MIA
# 3  14b6b90d5ae14da9dab933aa58665d4a  2022-04-23  2022-05-05             MIA
# 4  e3815febf57c2a01636fc121fde5702c  2022-04-23  2022-05-05             MIA
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                PHL        PT4H34M           False         False      False
# 1                PHL        PT8H28M           False         False      False
# 2                PHL        PT9H50M           False         False      False
# 3                PHL       PT10H50M           False         False      False
# 4                PHL        PT4H53M           False         False      False
#
# ...

# %%
df_MIA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875288 entries, 0 to 875287
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              875288 non-null  object
#  1   searchDate                         875288 non-null  object
#  2   flightDate                         875288 non-null  object
#  3   startingAirport                    875288 non-null  object
#  4   destinationAirport                 875288 non-null  object
#  5   travelDuration                     875288 non-null  object
#  6   isBasicEconomy                     875288 non-null  bool
#  7   isRefundable                       875288 non-null  bool
#  8   isNonStop                          875288 non-null  bool
#  9   totalFare                          875288 non-null  float64
#  10  totalTravelDistance                812419 non-null  float64
# ...

# %%
zip_dir_oak = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/OAK'

# Directory to extract CSV files
extract_dir_oak = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/OAK'

# The output CSV file where all data will be merged
output_csv_oak = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/OAK_merged.csv'

os.makedirs(extract_dir_oak, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_oak):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_oak, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_oak)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_oak, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_oak, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_oak}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/OAK_merged.csv.

# %%
df_OAK = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/OAK_merged.csv')

# %%
df_OAK.shape
# Out:
# (527105, 23)

# %%
df_OAK.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  e1b137527b9175d7d930c3af82e70ae0  2022-04-19  2022-05-20             OAK
# 1  d813ebd107e3fa700206c0d96015da7a  2022-04-19  2022-05-20             OAK
# 2  e8ece5ad6f5962c696e06e031fc2a24a  2022-04-19  2022-05-20             OAK
# 3  c004a54681335100f326c9613b3c9448  2022-04-19  2022-05-20             OAK
# 4  4a42bbf77211b4afa7b9e14005949120  2022-04-19  2022-05-20             OAK
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT7H52M           False         False      False
# 1                ATL        PT6H15M           False         False      False
# 2                ATL         PT9H6M           False         False      False
# 3                ATL        PT6H17M           False         False      False
# 4                ATL       PT14H12M           False         False      False
#
# ...

# %%
df_OAK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527105 entries, 0 to 527104
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              527105 non-null  object
#  1   searchDate                         527105 non-null  object
#  2   flightDate                         527105 non-null  object
#  3   startingAirport                    527105 non-null  object
#  4   destinationAirport                 527105 non-null  object
#  5   travelDuration                     527105 non-null  object
#  6   isBasicEconomy                     527105 non-null  bool
#  7   isRefundable                       527105 non-null  bool
#  8   isNonStop                          527105 non-null  bool
#  9   totalFare                          527105 non-null  float64
#  10  totalTravelDistance                459063 non-null  float64
# ...

# %%
zip_dir_ord = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/ORD'

# Directory to extract CSV files
extract_dir_ord = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/ORD'

# The output CSV file where all data will be merged
output_csv_ord = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ORD_merged.csv'

os.makedirs(extract_dir_ord, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_ord):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_ord, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_ord)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_ord, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_ord, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_ord}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ORD_merged.csv.

# %%
df_ORD = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/ORD_merged.csv')

# %%
df_ORD.shape
# Out:
# (894646, 23)

# %%
df_ORD.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  ef17c0e1048f064c375c765b10352536  2022-04-19  2022-06-08             ORD
# 1  3db26ea710b094b5fbbd200573db4e40  2022-04-19  2022-06-08             ORD
# 2  050659ff2132f7a97312aef0f6914049  2022-04-19  2022-06-08             ORD
# 3  19539cc757e0326566a1cb5a03dd9c5a  2022-04-19  2022-06-08             ORD
# 4  231a2babd63c7a8291acedec3e25b36c  2022-04-19  2022-06-08             ORD
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT2H10M           False         False       True
# 1                ATL        PT7H32M           False         False      False
# 2                ATL        PT1H54M            True         False       True
# 3                ATL        PT1H56M            True         False       True
# 4                ATL           PT2H           False         False       True
#
# ...

# %%
df_ORD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894646 entries, 0 to 894645
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              894646 non-null  object
#  1   searchDate                         894646 non-null  object
#  2   flightDate                         894646 non-null  object
#  3   startingAirport                    894646 non-null  object
#  4   destinationAirport                 894646 non-null  object
#  5   travelDuration                     894646 non-null  object
#  6   isBasicEconomy                     894646 non-null  bool
#  7   isRefundable                       894646 non-null  bool
#  8   isNonStop                          894646 non-null  bool
#  9   totalFare                          894646 non-null  float64
#  10  totalTravelDistance                812657 non-null  float64
# ...

# %%
zip_dir_phl = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/PHL'

# Directory to extract CSV files
extract_dir_phl = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/PHL'

# The output CSV file where all data will be merged
output_csv_phl = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/PHL_merged.csv'

os.makedirs(extract_dir_phl, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_phl):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_phl, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_phl)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_phl, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_phl, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_phl}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/PHL_merged.csv.

# %%
df_PHL = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/PHL_merged.csv')

# %%
df_PHL.shape
# Out:
# (785039, 23)

# %%
df_PHL.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  ddc255f14e33accbcb901849bab49d54  2022-05-06  2022-06-22             PHL
# 1  b08518a570f10b5bc713c377058e6bcd  2022-05-06  2022-06-22             PHL
# 2  c7c67edb42ab6c7eceec0a2531ae4ed3  2022-05-06  2022-06-22             PHL
# 3  80e675e8d9b2b795d6a9b540d1df0130  2022-05-06  2022-06-22             PHL
# 4  d7c748a588b0b9857dac2fcac2ce7740  2022-05-06  2022-06-22             PHL
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT2H20M           False         False       True
# 1                ATL        PT2H14M           False         False       True
# 2                ATL        PT2H16M           False         False       True
# 3                ATL        PT2H16M           False         False       True
# 4                ATL       PT11H37M           False         False      False
#
# ...

# %%
df_PHL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785039 entries, 0 to 785038
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              785039 non-null  object
#  1   searchDate                         785039 non-null  object
#  2   flightDate                         785039 non-null  object
#  3   startingAirport                    785039 non-null  object
#  4   destinationAirport                 785039 non-null  object
#  5   travelDuration                     785039 non-null  object
#  6   isBasicEconomy                     785039 non-null  bool
#  7   isRefundable                       785039 non-null  bool
#  8   isNonStop                          785039 non-null  bool
#  9   totalFare                          785039 non-null  float64
#  10  totalTravelDistance                719245 non-null  float64
# ...

# %%
zip_dir_sfo = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/external/SFO'

# Directory to extract CSV files
extract_dir_sfo = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/raw/SFO'

# The output CSV file where all data will be merged
output_csv_sfo = '/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/SFO_merged.csv'

os.makedirs(extract_dir_sfo, exist_ok=True)

# Flag to check if it's the first file (to write headers only once)
first_file = True

# Loop through all zip files in the zip_dir
for zip_file in os.listdir(zip_dir_sfo):
    if zip_file.endswith('.zip'):
        # Full path to the zip file
        zip_file_path = os.path.join(zip_dir_sfo, zip_file)
        
        # Open and extract all CSV files
        with zipfile.ZipFile(zip_file_path, 'r') as z:
            z.extractall(extract_dir_sfo)
            
            # Loop through the extracted files to process CSVs
            for extracted_file in z.namelist():
                if extracted_file.endswith('.csv'):
                    # Full path to the extracted CSV file
                    csv_file_path = os.path.join(extract_dir_sfo, extracted_file)
                    
                    # Read the CSV file in chunks (to handle large files)
                    for chunk in pd.read_csv(csv_file_path, chunksize=10000):
                        # Write to output CSV (append mode) without writing headers for subsequent files
                        chunk.to_csv(output_csv_sfo, mode='a', header=first_file, index=False)
                        
                        # After the first file is written, set flag to False
                        first_file = False

print(f"All files merged into {output_csv_sfo}.")
# Out:
# All files merged into /Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/SFO_merged.csv.

# %%
df_SFO = pd.read_csv('/Users/vega7unk/Documents/3rd_Sem_DSI/Adv_ML/AT3/at_3/adv_mla_at3/data/processed/SFO_merged.csv')

# %%
df_SFO.shape
# Out:
# (949046, 23)

# %%
df_SFO.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  b7dbcfb6d8d7b2b4ee9c87eb2512c573  2022-04-18  2022-05-21             SFO
# 1  a8a83aa27570391641f645d21a751603  2022-04-18  2022-05-21             SFO
# 2  8bc3b32cb7e932af662b3763a304ba8e  2022-04-18  2022-05-21             SFO
# 3  e2b6beb3d4866769050042bed886273c  2022-04-18  2022-05-21             SFO
# 4  8f1685cbc1f6504f7b337ce9f2dc209e  2022-04-18  2022-05-21             SFO
#
#   destinationAirport travelDuration  isBasicEconomy  isRefundable  isNonStop  \
# 0                ATL        PT7H19M           False         False      False
# 1                ATL        PT7H47M            True         False      False
# 2                ATL         PT9H7M            True         False      False
# 3                ATL        PT9H38M            True         False      False
# 4                ATL        PT10H7M            True         False      False
#
# ...

# %%
df_SFO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949046 entries, 0 to 949045
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   legId                              949046 non-null  object
#  1   searchDate                         949046 non-null  object
#  2   flightDate                         949046 non-null  object
#  3   startingAirport                    949046 non-null  object
#  4   destinationAirport                 949046 non-null  object
#  5   travelDuration                     949046 non-null  object
#  6   isBasicEconomy                     949046 non-null  bool
#  7   isRefundable                       949046 non-null  bool
#  8   isNonStop                          949046 non-null  bool
#  9   totalFare                          949046 non-null  float64
#  10  totalTravelDistance                942658 non-null  float64
# ...
